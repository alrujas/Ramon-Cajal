# %% [markdown]
# <a href="https://colab.research.google.com/github/alrujas/Ramon-Cajal/blob/Entrega1/TFG_David.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git config --global user.email "dj.gutierrez003@gmail.com"
# !git config --global user.name "DJBlue26"

# %%
# !git clone https://github.com/DJBlue26/TFG_David_Jim-nez_Guti-rrez.git
# %cd TFG_David_Jim-nez_Guti-rrez
# Out:
# Cloning into 'TFG_David_Jim-nez_Guti-rrez'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'TFG_David_Jim-nez_Guti-rrez'
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# %cd sample_data/
# Out:
# [Errno 2] No such file or directory: 'sample_data/'
# /content/sample_data

# %%
# !ls
# Out:
# anscombe.json		     california_housing_train.csv  mnist_train_small.csv
# california_housing_test.csv  mnist_test.csv		   README.md
